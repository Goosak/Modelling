# %%
import json

# %%
class

# %%
def read_json_by_path(path):
    with open(path,"r") as read_file:
        data = json.load(read_file)
        return data

# %%
read_json_by_path("irish.json")
# Out:
# {"Cooley's Reel": {'theme1': [[4, 7, 8],
#    [4, 6, 8],
#    [4, 4, 8],
#    [4, 11, 8],
#    [4, 11, 8],
#    [4, 9, 8],
#    [4, 11, 4],
#    [4, 4, 8],
#    [4, 11, 8],
#    [4, 11, 4],
#    [4, 9, 8],
#    [4, 11, 8],
#    [5, 2, 8],
#    [4, 11, 8],
#    [4, 9, 8],
#    [4, 7, 8],
#    [4, 6, 16],
#    [4, 4, 16],
#    [4, 2, 8],
#    [4, 9, 8],
#    [4, 2, 8],
#    [4, 11, 8],
#    [4, 2, 8],
#    [4, 9, 8],
#    [4, 2, 8],
#    [4, 6, 16],
#    [4, 4, 16],
#    [4, 2, 8],
#    [4, 9, 8],
#    [4, 2, 8],
#    [4, 11, 8],
#    [4, 9, 8],
#    [4, 7, 8],
#    [4, 6, 8],
#    [4, 4, 8],
#    [4, 11, 8],
#    [4, 11, 8],
#    [4, 9, 8],
#    [4, 11, 4],
#    [4, 4, 8],
#    [4, 11, 8],
#    [4, 11, 4],
#    [4, 9, 8],
#    [4, 11, 8],
#    [5, 2, 8],
#    [5, 4, 8],
#    [5, 6, 8],
#    [5, 7, 8],
#    [5, 9, 8],
#    [5, 6, 8],
#    [5, 4, 8],
#    [5, 1, 8],
#    [5, 2, 8],
#    [4, 11, 8],
#    [4, 9, 8],
#    [4, 6, 8],
#    [4, 2, 8],
#    [4, 4, 8],
#    [4, 6, 8],
# ...
